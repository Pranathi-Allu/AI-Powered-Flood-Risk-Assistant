# %%
# importing all necessary libraries
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# loading the precipitation dataset
data_preci = pd.read_csv(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\raw\precipitation\subset_GPM_3IMERGHH_07_20250831_085429_.txt", sep="\t")
print("Precipation data:")
print(data_preci.head())
# Out:
# Precipation data:
#   https://arthurhou.pps.eosdis.nasa.gov/Documents/IMERG_V07_ATBD_final.pdf
# 0  https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_...
# 1  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 2  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 3  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 4  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...

# %%
# loading a geopackage (GADM District boundaries)
data_gadm = gpd.read_file(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\raw\boundaries\gadm41_IND.gpkg")
print("GADM District boundaries data:")
data_gadm.head()
# Out:
# C:\Users\prana\anaconda3\Lib\site-packages\pyogrio\geopandas.py:275: UserWarning: More than one layer found in 'gadm41_IND.gpkg': 'ADM_ADM_0' (default), 'ADM_ADM_1', 'ADM_ADM_2', 'ADM_ADM_3'. Specify layer parameter to avoid this warning.
#   result = read_func(
# GADM District boundaries data:
#   GID_0 COUNTRY                                           geometry
# 0   IND   India  MULTIPOLYGON (((76.97542 8.38514, 76.97486 8.3...
# 1   Z01   India  MULTIPOLYGON (((75.07161 32.48296, 75.06268 32...
# 2   Z04   India  MULTIPOLYGON (((78.65135 32.09228, 78.65241 32...
# 3   Z05   India  MULTIPOLYGON (((80.08794 30.79071, 80.08796 30...
# 4   Z07   India  MULTIPOLYGON (((94.19125 27.49632, 94.1869 27....

# %%
# loading the shapefile of rivers
rivers = gpd.read_file(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\raw\hydro\HydroRIVERS_v10_as.shp")
print("Rivers data:")
rivers.head()
# Out:
# Rivers data:
#    HYRIV_ID  NEXT_DOWN  MAIN_RIV  LENGTH_KM  DIST_DN_KM  DIST_UP_KM  \
# 0  40000001   40000019  40017702       2.48      3056.6         6.9
# 1  40000002   40000019  40017702       1.23      3056.8         6.0
# 2  40000003   40000015  40017702       1.26      3052.8         7.4
# 3  40000004   40000015  40017702       1.30      3052.6         7.9
# 4  40000005   40000004  40017702       0.69      3054.1         6.4
#
#    CATCH_SKM  UPLAND_SKM  ENDORHEIC  DIS_AV_CMS  ORD_STRA  ORD_CLAS  ORD_FLOW  \
# 0      14.93        14.9          0       0.133         1         5         7
# 1      12.76        12.8          0       0.120         1         6         7
# 2      11.80        11.8          0       0.100         1         7         7
# 3       2.17        24.9          0       0.195         2         6         7
# 4      10.84        10.8          0       0.090         1         7         8
#
#     HYBAS_L12                                           geometry
# ...

# %%
# loading json (GADM boundaries)
with open(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\raw\boundaries\gadm41_IND_2.json") as f:
    gadm_json1 = json.load(f)
print("JSON Boundary keys:", list(gadm_json1.keys()))
# Out:
# JSON Boundary keys: ['type', 'name', 'crs', 'features']

# %%
pip install rasterio
# Out:
# ...
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.4 MB 1.6 MB/s eta 0:00:16
#    - -------------------------------------- 0.8/25.4 MB 1.6 MB/s eta 0:00:16
#    - -------------------------------------- 1.0/25.4 MB 1.1 MB/s eta 0:00:22
#    -- ------------------------------------- 1.3/25.4 MB 1.2 MB/s eta 0:00:20
#    -- ------------------------------------- 1.6/25.4 MB 1.1 MB/s eta 0:00:21
#    -- ------------------------------------- 1.8/25.4 MB 1.2 MB/s eta 0:00:20
#    -- ------------------------------------- 1.8/25.4 MB 1.2 MB/s eta 0:00:20
#    --- ------------------------------------ 2.1/25.4 MB 1.1 MB/s eta 0:00:22
#    --- ------------------------------------ 2.4/25.4 MB 1.1 MB/s eta 0:00:22
# ...

# %%
import rasterio
raster = rasterio.open(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\preprocessed\ind_ppp_2020_constrained.tif")
print("Raster info:", raster.meta)
# Out:
# Raster info: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': -99999.0, 'width': 35075, 'height': 34497, 'count': 1, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(0.0008333333300071276, 0.0, 68.185416409,
#        0.0, -0.0008333333299997101, 35.501250059)}

# %%
# exploring each dataset
for name, df in {"Precipitation": data_preci, "Rivers": rivers, "GADM": data_gadm}.items():
    print(f"\n{name} Dataset Info:")
    df.info()
# Out:
# Precipitation Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2833 entries, 0 to 2832
# Data columns (total 1 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   https://arthurhou.pps.eosdis.nasa.gov/Documents/IMERG_V07_ATBD_final.pdf  2833 non-null   object
# dtypes: object(1)
# memory usage: 22.3+ KB
#
# Rivers Dataset Info:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1428959 entries, 0 to 1428958
# Data columns (total 15 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   HYRIV_ID    1428959 non-null  int32
#  1   NEXT_DOWN   1428959 non-null  int32
#  2   MAIN_RIV    1428959 non-null  int32
#  3   LENGTH_KM   1428959 non-null  float64
#  4   DIST_DN_KM  1428959 non-null  float64
#  5   DIST_UP_KM  1428959 non-null  float64
# ...

# %%
print("\nSummary Stats:")
df.describe()
# Out:
# Summary Stats:
#        GID_0 COUNTRY                                           geometry
# count      6       6                                                  6
# unique     6       1                                                  6
# top      IND   India  MULTIPOLYGON (((76.97541809100011 8.3851404190...
# freq       1       6                                                  1

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# GID_0       0
# COUNTRY     0
# geometry    0
# dtype: int64

# %%
# Load elevation dataset
elevation = pd.read_csv(r"C:\ML Projects\AI Project\AI-Powered-Flood-Risk-Assistant\data\preprocessed\elevation\subset_GPM_3IMERGHH_07_20250831_085429_.txt", sep="\t")
elevation.head()
# Out:
#   https://arthurhou.pps.eosdis.nasa.gov/Documents/IMERG_V07_ATBD_final.pdf
# 0  https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_...
# 1  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 2  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 3  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...
# 4  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/...

# %%
# these are all the datasets needed for my project AI-Powered-Flood-Risk-Assistant.
# Some are of same extension files like "GADM Boundaries, i have same json files for gadm41_IND_2.json, gadm41_IND_3.json."
# So, I included only one file for loading. Same for other datasets also
